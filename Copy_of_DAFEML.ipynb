# %%
import pandas as pd
d=pd.read_csv('/content/Train.csv')
print(d)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
d.sample(5)# print random sample 5 rows
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 595            FDR08       18.700          Low Fat         0.037699
# 8039           FDY55       16.750          Low Fat         0.081485
# 231            FDG33          NaN          Regular         0.139561
# 4641           FDX24        8.355          Low Fat         0.013929
# 5185           FDV26          NaN          Regular         0.075792
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 595   Fruits and Vegetables  110.2886            OUT045
# 8039  Fruits and Vegetables  258.0988            OUT045
# 231                 Seafood  170.4764            OUT027
# 4641           Baking Goods   94.1462            OUT046
# 5185                  Dairy  193.3794            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 595                        2002         NaN               Tier 2
# 8039                       2002         NaN               Tier 2
# ...

# %%
d.shape # no of rows and columns
# Out:
# (8523, 12)

# %%
d.ndim
# Out:
# 2

# %%
d.size#rows product columns
# Out:
# 102276

# %%
d.columns#to know columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
d.info()# data description about columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
d.describe()# statistical summary report
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
d.count()#  total count of each and every column
# Out:
# Item_Identifier              8523
# Item_Weight                  7060
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Establishment_Year    8523
# Outlet_Size                  6113
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# dtype: int64

# %%
d.duplicated()# identify duplicate values if duplicate values are there then it will return true
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
d.corr()# variable is related to another variable
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
d.loc[:6:]# up to 6 rows all columns
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
#
# ...

# %%
d.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
d.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
d.isna().all()#from all values having null values or not
# Out:
# Item_Identifier              False
# Item_Weight                  False
# Item_Fat_Content             False
# Item_Visibility              False
# Item_Type                    False
# Item_MRP                     False
# Outlet_Identifier            False
# Outlet_Establishment_Year    False
# Outlet_Size                  False
# Outlet_Location_Type         False
# Outlet_Type                  False
# Item_Outlet_Sales            False
# dtype: bool

# %%
print(d.shape)#drop the columns which having null values
ds=d.dropna(axis=1)
ds.shape
# Out:
# (8523, 12)
# (8523, 10)

# %%
d.count().plot.hist()

# %%
d.Item_Weight.plot.hist()# item_identifier,item_fat_content,item_type,outlet_identifier,Outlet_Size,Outlet_Location_Type,Outlet_Type

# %%
d.Item_Visibility.plot.hist()

# %%
d.Item_MRP.plot.hist()

# %%
d.Outlet_Establishment_Year.plot.hist()

# %%
d.Item_Outlet_Sales.plot.hist()

# %%
d.count().plot.bar()# bar chart for total data set

# %%
d.Item_Weight.value_counts().plot.barh()

# %%
plt.bar(d.Item_Identifier,d.Item_Weight)
plt.show()

# %%
plt.bar(d.Item_Identifier,d.Item_Fat_Content)
plt.show()

# %%
plt.bar(d.Item_Identifier,d.Item_Visibility)
plt.show()

# %%
plt.bar(d.Item_Identifier,d.Item_Type)
plt.show()

# %%
plt.bar(d.Item_Identifier,d.Item_MRP)
plt.show()

# %%
plt.bar(d.Item_Identifier,d.Outlet_Identifier)
plt.show()

# %%
plt.bar(d.Item_Identifier,d.Outlet_Establishment_Year)
plt.show()

# %%
plt.bar(d.Item_Identifier,d.Outlet_Location_Type)
plt.show()

# %%
d.Item_Outlet_Sales.plot.box()

# %%
d.Item_Outlet_Sales.plot.hist(bins=12)

# %%
d.Item_Outlet_Sales.plot.kde()#kernal density estimation

# %%
d.Item_Weight.plot.box()

# %%
d.Item_Visibility.plot.box()

# %%
d.Item_MRP.plot.box()

# %%
d.Outlet_Establishment_Year.plot.box()

# %%
d.Item_Outlet_Sales.plot.box()

# %%
import seaborn as sns
sns.scatterplot(data=d.Item_Visibility)

# %%
sns.scatterplot(data=d.Item_Identifier)

# %%
sns.scatterplot(data=d.Item_Weight)

# %%
sns.scatterplot(data=d.Item_MRP)

# %%
sns.scatterplot(data=d.Item_Fat_Content)

# %%
sns.scatterplot(data=d.Item_Type)

# %%
sns.scatterplot(data=d.Outlet_Establishment_Year)

# %%
sns.scatterplot(data=d.Outlet_Size)

# %%
sns.scatterplot(x='Item_Identifier',y='Item_Weight',data=d,palette='blues')

# %%
sns.scatterplot(x='Item_Identifier',y='Item_Fat_Content',data=d)

# %%
sns.scatterplot(x='Item_Identifier',y='Item_Visibility',data=d)

# %%
sns.scatterplot(x='Item_Identifier',y='Item_Type',data=d)

# %%
sns.scatterplot(x='Item_Identifier',y='Item_MRP',data=d)

# %%
sns.scatterplot(x='Item_Identifier',y='Outlet_Identifier',data=d)

# %%
sns.scatterplot(x='Item_Identifier',y='Outlet_Establishment_Year',data=d)

# %%
sns.scatterplot(x='Item_Identifier',y='Outlet_Size',data=d)

# %%
sns.scatterplot(x='Item_Identifier',y='Outlet_Location_Type',data=d)

# %%
sns.violinplot(data=d.Item_MRP)

# %%
sns.lineplot(data=d.Item_MRP)

# %%
sns.pointplot(x=d.Item_Identifier,y=d.Item_MRP)

# %%
sns.regplot(x=d.Item_Identifier,y=d.Item_Weight)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-208-f62013271296> in <module>
# ----> 1 sns.regplot(x=d.Item_Identifier,y=d.Item_Weight)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
#     862     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...

# %%
sns.heatmap(d.corr())

# %%
sns.heatmap(d.corr(),annot=True)

# %%
sns.heatmap(d.corr(),annot=True,cmap='Reds')
